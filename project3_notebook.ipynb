# %%
import pandas as pd
from sqlalchemy import create_engine
from user import username, password

# %% [markdown]
# Import CSV Data

# %%
data = pd.read_csv('Resources/athlete_events.csv')

data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# Drop Height and Weight columns

# %%
olympic_data = data[['ID', 'Name', 'Sex', 'Age', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal']].copy()
# olympic_data.set_index('ID')
olympic_data.rename(columns= {'ID' : 'id', 'Name' : 'name', 'Sex' : 'sex', 'Age' : 'age', 'NOC' : 'noc', 'Games' : 'games', 'Year' : 'year', 'Season' : 'season', 'City' : 'city', 'Sport' : 'sport', 'Event' : 'event', 'Medal' : 'medal'},inplace = True)

olympic_data
# Out:
#             id                      name sex   age  noc        games  year  \
# 0            1                 A Dijiang   M  24.0  CHN  1992 Summer  1992
# 1            2                  A Lamusi   M  23.0  CHN  2012 Summer  2012
# 2            3       Gunnar Nielsen Aaby   M  24.0  DEN  1920 Summer  1920
# 3            4      Edgar Lindenau Aabye   M  34.0  DEN  1900 Summer  1900
# 4            5  Christine Jacoba Aaftink   F  21.0  NED  1988 Winter  1988
# ...        ...                       ...  ..   ...  ...          ...   ...
# 271111  135569                Andrzej ya   M  29.0  POL  1976 Winter  1976
# 271112  135570                  Piotr ya   M  27.0  POL  2014 Winter  2014
# 271113  135570                  Piotr ya   M  27.0  POL  2014 Winter  2014
# 271114  135571        Tomasz Ireneusz ya   M  30.0  POL  1998 Winter  1998
# 271115  135571        Tomasz Ireneusz ya   M  34.0  POL  2002 Winter  2002
#
#         season            city          sport  \
# ...

# %%
protocol = 'postgresql'
username = username
password = password
host = 'localhost'
port = 5432
database_name = 'olympic_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
olympic_data.to_sql(name='olympic_data', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from olympic_data', con=engine).head()
# Out:
#    id                      name sex   age  noc        games  year  season  \
# 0   1                 A Dijiang   M  24.0  CHN  1992 Summer  1992  Summer
# 1   2                  A Lamusi   M  23.0  CHN  2012 Summer  2012  Summer
# 2   3       Gunnar Nielsen Aaby   M  24.0  DEN  1920 Summer  1920  Summer
# 3   4      Edgar Lindenau Aabye   M  34.0  DEN  1900 Summer  1900  Summer
# 4   5  Christine Jacoba Aaftink   F  21.0  NED  1988 Winter  1988  Winter
#
#         city          sport                             event medal
# 0  Barcelona     Basketball       Basketball Men's Basketball  None
# 1     London           Judo      Judo Men's Extra-Lightweight  None
# 2  Antwerpen       Football           Football Men's Football  None
# 3      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4    Calgary  Speed Skating  Speed Skating Women's 500 metres  None

# %%
olympic_data = olympic_data[olympic_data.season=="Winter"]
olympic_data
# Out:
#             id                      name sex   age  noc        games  year  \
# 4            5  Christine Jacoba Aaftink   F  21.0  NED  1988 Winter  1988
# 5            5  Christine Jacoba Aaftink   F  21.0  NED  1988 Winter  1988
# 6            5  Christine Jacoba Aaftink   F  25.0  NED  1992 Winter  1992
# 7            5  Christine Jacoba Aaftink   F  25.0  NED  1992 Winter  1992
# 8            5  Christine Jacoba Aaftink   F  27.0  NED  1994 Winter  1994
# ...        ...                       ...  ..   ...  ...          ...   ...
# 271111  135569                Andrzej ya   M  29.0  POL  1976 Winter  1976
# 271112  135570                  Piotr ya   M  27.0  POL  2014 Winter  2014
# 271113  135570                  Piotr ya   M  27.0  POL  2014 Winter  2014
# 271114  135571        Tomasz Ireneusz ya   M  30.0  POL  1998 Winter  1998
# 271115  135571        Tomasz Ireneusz ya   M  34.0  POL  2002 Winter  2002
#
#         season            city          sport  \
# ...

# %%
unique_data = pd.DataFrame(olympic_data.groupby(["year", "noc", "event", "medal", "season"])["medal"].count())

unique_data.columns=["count"]
unique_data = unique_data.reset_index()
unique_data
# unique_data = pd.pivot_table(unique_data, "count",["year","noc", "event", "season"],"medal").fillna(0)
# unique_data = unique_data.reset_index()
# unique_data.tail(30)
# Out:
#       year  noc                            event   medal  season  count
# 0     1924  AUS          Alpinism Mixed Alpinism    Gold  Winter      1
# 1     1924  AUT     Figure Skating Men's Singles  Silver  Winter      1
# 2     1924  AUT       Figure Skating Mixed Pairs    Gold  Winter      2
# 3     1924  AUT   Figure Skating Women's Singles    Gold  Winter      1
# 4     1924  BEL        Bobsleigh Men's Four/Five  Bronze  Winter      5
# ...    ...  ...                              ...     ...     ...    ...
# 2848  2014  USA  Snowboarding Men's Boardercross  Bronze  Winter      1
# 2849  2014  USA    Snowboarding Men's Slopestyle    Gold  Winter      1
# 2850  2014  USA    Snowboarding Women's Halfpipe  Bronze  Winter      1
# 2851  2014  USA    Snowboarding Women's Halfpipe    Gold  Winter      1
# 2852  2014  USA  Snowboarding Women's Slopestyle    Gold  Winter      1
#
# [2853 rows x 6 columns]

# %%
# NOC = unique_data["noc"].unique()
# NOC

# Medal_dict = {}

# for NOC in NOC:
#     for row in unique_data:
#         Bronze_Count = 0
#         Silver_Count = 0
#         Gold_Count = 0
#         if unique_data["noc"] == NOC:

#             if unique_data["Bronze"] > 0:
#                 Bronze_Count = Bronze_Count + 1
#             if unique_data["Silver"] > 0:
#                 Silver_Count = Silver_Count + 1
#             if unique_data["Gold"] > 0:
#                 Gold_Count = Gold_Count + 1
#     Medal_dict[NOC] = [Bronze_Count,Silver_Count,Gold_Count]

# Medal_dict
from dataclasses import replace


New_data = unique_data.copy()


New_data['Bronze'].values[New_data['Bronze'] > 1] = 1
New_data['Silver'].values[New_data['Silver'] > 1] = 1
New_data['Gold'].values[New_data['Gold'] > 1] = 1

grouped_data = New_data.groupby('noc').sum()
grouped_data = grouped_data.reset_index()[['noc', 'Gold', 'Silver', 'Bronze']]
grouped_data['noc']
# Bronze_list = New_data['Bronze'].to_list()

# Bronze_list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\calum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bronze'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24440\167017048.py in <module>
#      26
# ...
